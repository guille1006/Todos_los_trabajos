# %%
from sklearn.datasets import load_digits

dataset = load_digits(as_frame=True)
X = dataset["data"]
y = dataset["target"]

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X, y)
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.coef_
# Out:
# array([[ 0.00000000e+00, -5.53684522e-03, -4.12966758e-02,
#          9.48921205e-02,  1.10303661e-02, -1.00102964e-01,
#         -1.21827765e-01, -1.18914006e-02, -1.54866805e-04,
#         -5.59529767e-02,  3.03812401e-02,  1.53331879e-01,
#          8.82732555e-02,  1.31064360e-01, -5.14184614e-02,
#         -1.19487446e-02, -1.71473214e-04,  4.12884350e-02,
#          2.01151212e-01, -3.72258310e-02, -3.59430592e-01,
#          1.97287598e-01,  8.58399906e-02, -4.10956711e-03,
#         -7.79979901e-05,  1.53406492e-01,  1.26780326e-01,
#         -2.42583277e-01, -5.46084634e-01,  2.88884164e-02,
#          9.57484719e-02, -2.74651782e-04,  0.00000000e+00,
#          1.87298010e-01,  1.21176239e-01, -2.53093952e-01,
#         -4.78459509e-01,  4.09599047e-02,  6.77240709e-02,
#          0.00000000e+00, -6.74017597e-04, -2.56872138e-02,
#          3.00277996e-01, -1.76011980e-01, -1.57504444e-01,
#          1.13776733e-01,  3.51281123e-02, -7.59344829e-04,
# ...

# %%
model.score(X, y)
# Out:
# 1.0

# %%
from pickle import load, dump

dump(model, open(".\logisticregression.pkl", "wb"))
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7352\1417709295.py:3: SyntaxWarning: invalid escape sequence '\l'
#   dump(model, open(".\logisticregression.pkl", "wb"))

# %%
# !dir
# Out:
#  El volumen de la unidad C es Windows
#  El n�mero de serie del volumen es: E29C-9D12
#
#  Directorio de c:\Users\Usuario\Desktop\Ejercicios de uni\Ejercicio 13 Machine learning
#
# 14/03/2025  17:27    <DIR>          .
# 14/03/2025  17:27    <DIR>          ..
# 14/03/2025  16:23                 0 Ejercicio.ipynb
# 14/03/2025  17:27             6.754 logisticregression.pkl
# 14/03/2025  17:07    <DIR>          venv
#                2 archivos          6.754 bytes
#                3 dirs   6.652.514.304 bytes libres

# %%
model2 = load(open(".\logisticregression.pkl", "rb"))
model2.score(X, y)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7352\1366809895.py:1: SyntaxWarning: invalid escape sequence '\l'
#   model2 = load(open(".\logisticregression.pkl", "rb"))
# 1.0

# %% [markdown]
# # Modelo 2

# %%
from sklearn.model_selection import train_test_split

seed = 66666
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=2, random_state=seed)

X_train
# Out:
#       pixel_0_0  pixel_0_1  pixel_0_2  pixel_0_3  pixel_0_4  pixel_0_5  \
# 1291        0.0        0.0        0.0        2.0       15.0        2.0
# 534         0.0        0.0        0.0        9.0       16.0        6.0
# 790         0.0        0.0        0.0        8.0       15.0        5.0
# 1613        0.0        0.0        0.0       14.0        7.0        0.0
# 1429        0.0        0.0        0.0       10.0       12.0        0.0
# ...         ...        ...        ...        ...        ...        ...
# 1684        0.0        0.0        4.0       16.0       16.0       16.0
# 172         0.0        0.0        0.0        0.0       14.0       16.0
# 315         0.0        2.0       11.0       16.0       15.0        2.0
# 930         0.0        0.0        9.0       12.0       14.0        2.0
# 604         0.0        0.0        2.0       13.0       16.0        8.0
#
#       pixel_0_6  pixel_0_7  pixel_1_0  pixel_1_1  ...  pixel_6_6  pixel_6_7  \
# ...

# %%
model = LogisticRegression(random_state=seed)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 1.0

# %% [markdown]
# # Modelo 3

# %%
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
alg = LogisticRegression()
model = make_pipeline(scaler, alg)


X_train, y_train, X_test, y_test = train_test_split(X, y, random_state=777)
model.fit(X_train, y_test)

# %%
model.steps[-1][1].coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 model.steps[-1][1].coef_
#
# AttributeError: 'LogisticRegression' object has no attribute 'steps'
