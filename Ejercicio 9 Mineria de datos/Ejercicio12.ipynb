# %%
import geopandas as gdp
import matplotlib.pyplot as plt
from pysal.lib import weights

gdfm = gdp.read_file("2_Espacial/CartografiasDatos_Python/cartografias/Munic04_ESP.shp")

wq = weights.contiguity.Queen.from_dataframe(gdfm)

ax = gdfm.plot(
    edgecolor="grey", 
    facecolor="w",
    figsize=(15,15))

plt.xlim(-2.5,2.5)
plt.ylim(37,40)

wq.plot(
    gdfm, 
    edge_kws=dict(linewidth=0.75, color="orangered"),
    node_kws=dict(marker="*"),
    ax=ax
)
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_29636\1847123859.py:7: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   wq = weights.contiguity.Queen.from_dataframe(gdfm)
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\contiguity.py:347: UserWarning: The weights matrix is not fully connected:
#  There are 19 disconnected components.
#  There are 8 islands with ids: 816, 2536, 5326, 7061, 7160, 7229, 8106, 8107.
#   W.__init__(self, neighbors, ids=ids, **kw)
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# ...
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1484: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.loc[neighbors].centroid
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\libpysal\weights\weights.py:1496: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = gdf.centroid
